# %% [markdown]
# ## 1 - How do you import pandas library

# %%
import pandas as pd

# %% [markdown]
# ## 2- Create Dateframe and Print it

# %%
# create a dataframe from the D
## use these Samples : 'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]

# %%
# Write Your Code Below

# %%
dic = {'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]}
df = pd.DataFrame(dic)

# %% [markdown]
# ## 3 - Create Series and Print it

# %%
# use these Samples : [2, 4, 6, 8, 10]

# %%
# Write Your Code Below

# %%
list = [2, 4, 6, 8, 10]
ser = pd.Series(list)
ser
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %% [markdown]
# ## 4 -  Read the Data

# %%
# Write Your Code Below
data = pd.read_csv("MovieAssignmentData.csv")
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# ## Task 1: Cleaning the Data
# ### Subtask 1.1: Inspect Null values
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here
missing = data.isna().sum(axis=0)
missing
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# Write your code for row-wise null count here
data.isnull().count(axis=1).head(10)
# Out:
# 0    28
# 1    28
# 2    28
# 3    28
# 4    28
# 5    28
# 6    28
# 7    28
# 8    28
# 9    28
# dtype: int64

# %%
# Write your code for column-wise null percentages here
percentage = missing*100/len(data)
percentage.round(2)
# Out:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.24
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# aspect_ratio                  6.52
# ...

# %% [markdown]
# ### Subtask 1.2: Drop unecessary columns
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
#
# * color
# * director_facebook_likes
# * actor_1_facebook_likes
# * actor_2_facebook_likes
# * actor_3_facebook_likes
# * actor_2_name
# * cast_total_facebook_likes
# * actor_3_name
# * duration
# * facenumber_in_poster
# * content_rating
# * country
# * movie_imdb_link
# * aspect_ratio
# * plot_keywords

# %%
# Write your code for dropping the columns here.
data.drop(['color','director_facebook_likes','actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes','actor_2_name',
'cast_total_facebook_likes','actor_3_name','duration','facenumber_in_poster','content_rating','country','movie_imdb_link','aspect_ratio','plot_keywords'],axis =1,inplace=True)

# %%
# print the datafreame head
data.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 4        Doug Walker                     NaN          NaN
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                          movie_title  num_voted_users  \
# 0                                            Avatar            886204
# 1          Pirates of the Caribbean: At World's End            471220
# 2                                           Spectre            275868
# ...

# %%
# print columns names 
data.columns
# Out:
# Index([u'director_name', u'num_critic_for_reviews', u'gross', u'genres',
#        u'actor_1_name', u'movie_title', u'num_voted_users',
#        u'num_user_for_reviews', u'language', u'budget', u'title_year',
#        u'imdb_score', u'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# ## Subtask 2.1: Fill NaN values
# You might notice that the language column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with 'English'.

# %%
# Fill the NaN values in the 'language' column here
data['language'].fillna('English')
# Out:
# 0        English
# 1        English
# 2        English
# 3        English
# 4        English
# 5        English
# 6        English
# 7        English
# 8        English
# 9        English
# 10       English
# 11       English
# 12       English
# 13       English
# 14       English
# 15       English
# 16       English
# 17       English
# 18       English
# 19       English
# 20       English
# 21       English
# 22       English
# 23       English
# 24       English
# 25       English
# 26       English
# 27       English
# 28       English
# 29       English
#           ...
# 5013     English
# 5014     English
# 5015     English
# 5016     English
# 5017     English
# 5018     English
# 5019     English
# 5020     English
# 5021     English
# 5022     Swahili
# 5023     English
# 5024     English
# 5025     English
# 5026      French
# 5027     Persian
# 5028     English
# 5029    Japanese
# 5030     English
# 5031     English
# 5032     English
# 5033     English
# ...

# %% [markdown]
# ## Subtask 2.2: Drop duplicate values

# %%
# Write your code for dropping duplicate values here

# %%
data.duplicated().sum()
# Out:
# 47

# %%
data.drop_duplicates(inplace = True)
data.duplicated().sum()
# Out:
# 0

# %%
# Write your code for creating new dataframe called Meryl_Streep which contain only "Meryl Streep" from actor_1_name 
Meryl_Streep = data.loc[data['actor_1_name'] == "Meryl Streep"]
Meryl_Streep.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 410     Nancy Meyers                   187.0  112703470.0
# 1106   Curtis Hanson                    42.0   46815748.0
# 1204     Nora Ephron                   252.0   94125426.0
# 1408   David Frankel                   208.0  124732962.0
# 1483  Robert Redford                   227.0   14998070.0
#
#                                genres  actor_1_name             movie_title  \
# 410              Comedy|Drama|Romance  Meryl Streep       It's Complicated
# 1106  Action|Adventure|Crime|Thriller  Meryl Streep         The River Wild
# 1204          Biography|Drama|Romance  Meryl Streep          Julie & Julia
# 1408             Comedy|Drama|Romance  Meryl Streep  The Devil Wears Prada
# 1483               Drama|Thriller|War  Meryl Streep        Lions for Lambs
#
#       num_voted_users  num_user_for_reviews language      budget  title_year  \
# 410             69860                 214.0  English  85000000.0      2009.0
# ...

# %%
# Write your code for creating new dataframe called Brad_Pitt  which contain only "Brad Pitt" from actor_1_name 
Brad_Pitt = data.loc[data['actor_1_name'] == "Brad Pitt"]
Brad_Pitt.head()
# Out:
#          director_name  num_critic_for_reviews        gross  \
# 101      David Fincher                   362.0  127490802.0
# 147  Wolfgang Petersen                   220.0  133228348.0
# 254  Steven Soderbergh                   198.0  125531634.0
# 255         Doug Liman                   233.0  186336103.0
# 382         Tony Scott                   142.0      26871.0
#
#                                    genres actor_1_name  \
# 101                 Drama|Fantasy|Romance    Brad Pitt
# 147                             Adventure    Brad Pitt
# 254                        Crime|Thriller    Brad Pitt
# 255  Action|Comedy|Crime|Romance|Thriller    Brad Pitt
# 382                 Action|Crime|Thriller    Brad Pitt
#
#                               movie_title  num_voted_users  \
# 101  The Curious Case of Benjamin Button            459346
# 147                                 Troy            381672
# 254                       Ocean's Twelve            284852
# ...

# %%
# Write your code for creating new dataframes called Leo_Caprio which contain only "Leonardo DiCaprio" from actor_1_name 
Leo_Caprio = data.loc[data['actor_1_name'] == "Leonardo DiCaprio"]
Leo_Caprio.head()
# Out:
#              director_name  num_critic_for_reviews        gross  \
# 26           James Cameron                   315.0  658672302.0
# 50            Baz Luhrmann                   490.0  144812796.0
# 97       Christopher Nolan                   642.0  292568851.0
# 179  Alejandro G. Iñárritu                   556.0  183635922.0
# 257        Martin Scorsese                   267.0  102608827.0
#
#                                genres       actor_1_name        movie_title  \
# 26                      Drama|Romance  Leonardo DiCaprio           Titanic
# 50                      Drama|Romance  Leonardo DiCaprio  The Great Gatsby
# 97   Action|Adventure|Sci-Fi|Thriller  Leonardo DiCaprio         Inception
# 179  Adventure|Drama|Thriller|Western  Leonardo DiCaprio      The Revenant
# 257                   Biography|Drama  Leonardo DiCaprio       The Aviator
#
#      num_voted_users  num_user_for_reviews language       budget  title_year  \
# ...

# %%
# Write your code for combining the three dataframes at "combined" 
frames = [Meryl_Streep,Brad_Pitt,Leo_Caprio]
combined = pd.concat(frames)

# %%
# print combined

# %%
combined
# Out:
#               director_name  num_critic_for_reviews        gross  \
# 410            Nancy Meyers                   187.0  112703470.0
# 1106          Curtis Hanson                    42.0   46815748.0
# 1204            Nora Ephron                   252.0   94125426.0
# 1408          David Frankel                   208.0  124732962.0
# 1483         Robert Redford                   227.0   14998070.0
# 1575         Sydney Pollack                    66.0   87100000.0
# 1618          David Frankel                   234.0   63536011.0
# 1674          Carl Franklin                    64.0   23209440.0
# 1752         Stephen Frears                    87.0          NaN
# 1925         Stephen Daldry                   174.0   41597830.0
# 2781         Phyllida Lloyd                   331.0   29959436.0
# 3135          Robert Altman                   211.0   20338609.0
# 3641         Fred Zinnemann                    38.0          NaN
# ...
